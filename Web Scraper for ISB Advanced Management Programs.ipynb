# %% [markdown]
# #### **Step 1-** Defining libraries and accessing the URL

# %% [markdown]
# https://www.isb.edu/en/study-isb/advanced-management-programmes.html

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Specify the correct path to your chromedriver executable
chromedriver_path = "C:/Program Files (x86)/chromedriver.exe"  

# Initialize the Chrome WebDriver using the Service class
service = Service(executable_path=chromedriver_path)

# %%
from selenium.webdriver.common.keys import Keys
# This class provides keys in the keyboard like RETURN, F1, ALT, etc. 
# It is useful when you need to simulate keypresses in your Selenium 
# scripts. For instance, after filling out a text field, you might want 
# to simulate pressing the Enter key to submit the form.
from selenium.webdriver.common.by import By
# This class provides methods for locating elements within a page. 
# It is used with find_element(s)_by methods to specify how Selenium 
# should search for elements. The options include searching by ID, name, 
# XPath, link text, partial link text, tag name, or class name.
# Using By makes your code more readable and maintainable

# %%
driver = webdriver.Chrome(service=service) 
# This starts a new chrome browser session
# You should see a new window open up in chrome 
# In effect you can now control all browser actions using code
# To control the browser that you just opened, you need to go through
# the driver object you created

# driver.quit() # to close full browser
# driver.close() # to close tab

# %%
driver.get("https://www.isb.edu/en/study-isb/advanced-management-programmes.html") 
# You are now telling the driver to load the webpage specified by the URL
# The driver.get method will navigate to a page given by the URL. 
# WebDriver will wait until the page has fully loaded before returning 
# control to your script.

# %% [markdown]
# #### **Step 2-** Finding Elements and Extracting HTML

# %% [markdown]
# <span style='color:Blue'> We need to extract the following information about each program. <br>
# (i) Title <br>
# (ii) Brief description <br>
# (iii) Duration <br>
# (iv) Work Experience  </span>

# %%
# Inspect the website HTML code. All data we need is in the 'body' element.
# It has an ID. Note that ID is a unique tag on a website. We will extract 'body'
body = driver.find_element(By.ID, "page-7ea680bf20")

# %%
# Let us try to understand this object
help(body)
# Out:
# Help on WebElement in module selenium.webdriver.remote.webelement object:
#
# class WebElement(BaseWebElement)
#  |  WebElement(parent, id_) -> 'None'
#  |
#  |  Represents a DOM element.
#  |
#  |  Generally, all interesting operations that interact with a document will be
#  |  performed through this interface.
#  |
#  |  All method calls will do a freshness check to ensure that the element
#  |  reference is still valid.  This essentially determines whether the
#  |  element is still attached to the DOM.  If this test fails, then an
#  |  ``StaleElementReferenceException`` is thrown, and all future calls to this
#  |  instance will fail.
#  |
#  |  Method resolution order:
#  |      WebElement
#  |      BaseWebElement
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, element)
#  |      Return self==value.
#  |
#  |  __hash__(self) -> 'int'
#  |      Return hash(self).
#  |
#  |  __init__(self, parent, id_) -> 'None'
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ne__(self, element)
#  |      Return self!=value.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  clear(self) -> 'None'
#  |      Clears the text if it's a text entry element.
#  |
#  |  click(self) -> 'None'
#  |      Clicks the element.
#  |
#  |  find_element(self, by='id', value=None) -> 'WebElement'
#  |      Find an element given a By strategy and locator.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              element = element.find_element(By.ID, 'foo')
#  |
#  |      :rtype: WebElement
#  |
#  |  find_elements(self, by='id', value=None) -> 'List[WebElement]'
#  |      Find elements given a By strategy and locator.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              element = element.find_elements(By.CLASS_NAME, 'foo')
#  |
#  |      :rtype: list of WebElement
#  |
#  |  get_attribute(self, name) -> 'str | None'
#  |      Gets the given attribute or property of the element.
#  |
#  |      This method will first try to return the value of a property with the
#  |      given name. If a property with that name doesn't exist, it returns the
#  |      value of the attribute with the same name. If there's no attribute with
#  |      that name, ``None`` is returned.
#  |
#  |      Values which are considered truthy, that is equals "true" or "false",
#  |      are returned as booleans.  All other non-``None`` values are returned
#  |      as strings.  For attributes or properties which do not exist, ``None``
#  |      is returned.
#  |
#  |      To obtain the exact value of the attribute or property,
#  |      use :func:`~selenium.webdriver.remote.BaseWebElement.get_dom_attribute` or
#  |      :func:`~selenium.webdriver.remote.BaseWebElement.get_property` methods respectively.
#  |
#  |      :Args:
#  |          - name - Name of the attribute/property to retrieve.
#  |
#  |      Example::
#  |
#  |          # Check if the "active" CSS class is applied to an element.
#  |          is_active = "active" in target_element.get_attribute("class")
#  |
#  |  get_dom_attribute(self, name) -> 'str'
#  |      Gets the given attribute of the element. Unlike
#  |      :func:`~selenium.webdriver.remote.BaseWebElement.get_attribute`, this
#  |      method only returns attributes declared in the element's HTML markup.
#  |
#  |      :Args:
#  |          - name - Name of the attribute to retrieve.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              text_length = target_element.get_dom_attribute("class")
#  |
#  |  get_property(self, name) -> 'str | bool | WebElement | dict'
#  |      Gets the given property of the element.
#  |
#  |      :Args:
#  |          - name - Name of the property to retrieve.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              text_length = target_element.get_property("text_length")
#  |
#  |  is_displayed(self) -> 'bool'
#  |      Whether the element is visible to a user.
#  |
#  |  is_enabled(self) -> 'bool'
#  |      Returns whether the element is enabled.
#  |
#  |  is_selected(self) -> 'bool'
#  |      Returns whether the element is selected.
#  |
#  |      Can be used to check if a checkbox or radio button is selected.
#  |
#  |  screenshot(self, filename) -> 'bool'
#  |      Saves a screenshot of the current element to a PNG image file.
#  |      Returns False if there is any IOError, else returns True. Use full
#  |      paths in your filename.
#  |
#  |      :Args:
#  |       - filename: The full path you wish to save your screenshot to. This
#  |         should end with a `.png` extension.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              element.screenshot('/Screenshots/foo.png')
#  |
#  |  send_keys(self, *value: 'str') -> 'None'
#  |      Simulates typing into the element.
#  |
#  |      :Args:
#  |          - value - A string for typing, or setting form fields.  For setting
#  |            file inputs, this could be a local file path.
#  |
#  |      Use this to send simple key events or to fill out form fields::
#  |
#  |          form_textfield = driver.find_element(By.NAME, 'username')
#  |          form_textfield.send_keys("admin")
#  |
#  |      This can also be used to set file inputs.
#  |
#  |      ::
#  |
#  |          file_input = driver.find_element(By.NAME, 'profilePic')
#  |          file_input.send_keys("path/to/profilepic.gif")
#  |          # Generally it's better to wrap the file path in one of the methods
#  |          # in os.path to return the actual path to support cross OS testing.
#  |          # file_input.send_keys(os.path.abspath("path/to/profilepic.gif"))
#  |
#  |  submit(self) -> 'None'
#  |      Submits a form.
#  |
#  |  value_of_css_property(self, property_name) -> 'str'
#  |      The value of a CSS property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  accessible_name
#  |      Returns the ARIA Level of the current webelement.
#  |
#  |  aria_role
#  |      Returns the ARIA role of the current web element.
#  |
#  |  id
#  |      Internal ID used by selenium.
#  |
#  |      This is mainly for internal use. Simple use cases such as checking if 2
#  |      webelements refer to the same element, can be done using ``==``::
#  |
#  |          if element1 == element2:
#  |              print("These 2 are equal")
#  |
#  |  location
#  |      The location of the element in the renderable canvas.
#  |
#  |  location_once_scrolled_into_view
#  |      THIS PROPERTY MAY CHANGE WITHOUT WARNING. Use this to discover where
#  |      on the screen an element is so that we can click it. This method should
#  |      cause the element to be scrolled into view.
#  |
#  |      Returns the top lefthand corner location on the screen, or zero
#  |      coordinates if the element is not visible.
#  |
#  |  parent
#  |      Internal reference to the WebDriver instance this element was found
#  |      from.
#  |
#  |  rect
#  |      A dictionary with the size and location of the element.
#  |
#  |  screenshot_as_base64
#  |      Gets the screenshot of the current element as a base64 encoded
#  |      string.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              img_b64 = element.screenshot_as_base64
#  |
#  |  screenshot_as_png
#  |      Gets the screenshot of the current element as a binary data.
#  |
#  |      :Usage:
#  |          ::
#  |
#  |              element_png = element.screenshot_as_png
#  |
#  |  shadow_root
#  |      Returns a shadow root of the element if there is one or an error.
#  |      Only works from Chromium 96, Firefox 96, and Safari 16.4 onwards.
#  |
#  |      :Returns:
#  |        - ShadowRoot object or
#  |        - NoSuchShadowRoot - if no shadow root was attached to element
#  |
#  |  size
#  |      The size of the element.
#  |
#  |  tag_name
#  |      This element's ``tagName`` property.
#  |
#  |  text
#  |      The text of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseWebElement:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
# To get the full HTML of the body element, we can ask for the outerHTML attribute
html_body = body.get_attribute('outerHTML')
print(html_body)
# Out:
# <body class="page basicpage chrome chrome127" id="page-7ea680bf20" data-cmp-data-layer-enabled="">
#         <script>
#           window.adobeDataLayer = window.adobeDataLayer || [];
#           adobeDataLayer.push({
#               page: JSON.parse("{\x22page\u002D7ea680bf20\x22:{\x22@type\x22:\x22isb\/components\/structure\/page\x22,\x22repo:modifyDate\x22:\x222024\u002D05\u002D21T09:47:58Z\x22,\x22dc:title\x22:\x22Advanced Management Programme\x22,\x22xdm:template\x22:\x22\/conf\/isb\u002Duniversity\u002Dtemplates\/settings\/wcm\/templates\/content\u002Dpage\x22,\x22xdm:language\x22:\x22en\x22,\x22xdm:tags\x22:[],\x22repo:path\x22:\x22\/content\/sites\/isb\/en\/study\u002Disb\/advanced\u002Dmanagement\u002Dprogrammes.html\x22}}"),
#               event:'cmp:show',
#               eventInfo: {
#                   path: 'page.page\u002D7ea680bf20'
#               }
#           });
#         </script>
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript>
#     <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PWQVPHJ" height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <div id="analytics" class="hidden">
#     {
#   "page": {
#     "pageInfo": {
#       "pageType": "Others"
#     },
#     "components": [],
#     "section": "isb:en:study-isb:advanced-management-programmes",
#     "pageName": "Advanced Management Programme"
#   },
#   "events": [],
#   "form": [],
#   "search": {},
#   "file": [],
#   "user": [],
#   "error": []
# }
# </div>
# <input type="hidden" id="currentPagePath" value="/content/sites/isb/en/study-isb/advanced-management-programmes">
# <input type="hidden" id="wcmdisabled" value="true">
# <div id="important-data" class="hidden">
#     {
#     "salesforceUrl":"https://webto.salesforce.com/servlet/servlet.WebToLead?encoding=UTF-8"
#     , "solrUrl":"https://www.isb.edu/solr/university"
# 	,  "initialRouteUrl":"https://hrm.exchange.isb.edu/ProdAEMEvents/Articles"
#     ,  "siteName":"isb"
#     ,  "serverDownMessage":"Internal server error, please try again after some time"
#     }
# </div>
#
# <p id="utm-params" class="hidden">
#
# 	    [{"text":"00N0I00000KT1fD","value":"utm_source"},{"text":"00N0I00000KT1fI","value":"utm_medium"},{"text":"00N0I00000KT1fN","value":"utm_campaign"},{"text":"00N0I00000KT1fS","value":"uterm"},{"text":"00N0I00000KT1md","value":"adgroupname"},{"text":"00N0I00000KT1mx","value":"keyword"},{"text":"00N0I00000KT1nR","value":"creative"},{"text":"00N0I00000KT1ng","value":"devicemodel"},{"text":"00N0I00000KT1nq","value":"placement"},{"text":"00N0I00000KT1ot","value":"target"},{"text":"00N0I00000KT1o0","value":"device"},{"text":"00N0I00000KT1o5","value":"network"},{"text":"00N0I00000KT1oA","value":"matchtype"},{"text":"00N0I00000KT1oF","value":"gclid"},{"text":"00N0I00000KT1nM","value":"campaignname"},{"text":"00N0I00000KT1n7","value":"term"},{"text":"","value":""}]
#
#
# </p>
#
#
# <div class="">
#     <div class="container-wrap">
#         <p style="display:none" id="showPageMetadata"></p>
#         <p style="display:none" id="pagePublishedDate" data-value="May 22, 2024"> </p>
#         <p style="display:none" id="pageTags"></p>
#         <div class="root responsivegrid">
#
#
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12 ">
#
#     <div class="experience-fragment experiencefragment aem-GridColumn aem-GridColumn--default--12">
# <div id="experience-fragment-11809195ca" class="cmp-experiencefragment cmp-experiencefragment--experience-fragment-for-header">
#
#
#
#
#
# <div class="xf-content-height">
#
#
#
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12 ">
#
#     <div class="header aem-GridColumn aem-GridColumn--default--12">
#
#
#
#
# <style>
#     .greeting {
#         font-weight:bold;
#         padding : 15px;
#         width:100%;
#         display:none;
#         border : 1px solid lightgreen;
#     }
# </style>
#
# <input type="hidden" id="__cookie__">
#
# <div class="header-wrapper" data-isb-component-info="{ &quot;componentName&quot;: &quot;Header&quot; }">
#
#
#     <header class="">
#         <div class="container">
#             <div class="flex">
#                 <figure>
#                     <a href="/" class="logo" title=""><img loading="lazy" src="/content/dam/sites/diri/logo.png" alt="logo-profile"></a>
#                 </figure>
#                 <nav class="hidden-xs hidden-sm">
#
#
#                             <ul class="top-nav">
#
#                                     <li><a href="/en/news.html" title="News" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;News&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/news.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">News</a></li>
#
#                                     <li><a href="/en/news-events/events-grid.html" title="Events" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Events&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/news-events/events-grid.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Events</a></li>
#
#                                     <li><a href="https://er.isb.edu/en.html" title="External Relations" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;External Relations&quot;, &quot;linkUrl&quot;:&quot;https://er.isb.edu/en.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">External Relations</a></li>
#
#                                     <li><a href="/en/i-ventute---isb.html" title="I-Venture @ ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;I-Venture @ ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/i-ventute---isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">I-Venture @ ISB</a></li>
#
#                                     <li><a href="/en/alumni.html" title="Alumni" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Alumni&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/alumni.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Alumni</a></li>
#
#                                     <li><a href="/en/hire-from-isb.html" title="Hire from ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Hire from ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/hire-from-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Hire from ISB</a></li>
#
#                                     <li><a href="/en/careers/careers-at-isb.html" title="Careers" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Careers&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/careers/careers-at-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Careers</a></li>
#
#                                     <li><a href="/en/give-to-isb.html" title="Give to ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Give to ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/give-to-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Give to ISB</a></li>
#
#
#                                 <li>
#                                     <a href="#searchModal" data-toggle="modal" title="Search Overlay" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Search Overlay&quot;, &quot;linkPosition&quot;:&quot;Header&quot;}"><img loading="lazy" src="/content/dam/sites/isb/icons/search.svg" alt="svgicon"></a>
#                                 </li>
#
#
#                             </ul>
#
#
#
#
#                     <div class="main-nav">
#                         <ul>
#                             <li class="sub-menu">
#                                 <a href="/en/about-isb.html" title="ABOUT ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;ABOUT ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">ABOUT ISB</a>
#                                 <div class="dropdown-content">
#                                     <ul>
#                                         <li><a href="/en/about-isb/leadership.html" title="Leadership" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/about-isb/leadership.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Leadership&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/leadership.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Leadership</a></li>
#
#                                         <li><a href="/en/about-isb/isb-advantage.html" title="ISB Advantage" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/about-isb/isb-advantage.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;ISB Advantage&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/isb-advantage.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">ISB Advantage</a></li>
#
#                                         <li><a href="/en/about-isb/partnerships-associations.html" title="Partnerships &amp; Associations" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/about-isb/partnerships-associations.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Partnerships &amp; Associations&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/partnerships-associations.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Partnerships &amp; Associations</a></li>
#
#                                         <li><a href="/en/about-isb/history-milestones.html" title="History &amp; Milestones" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/about-isb/history-milestones.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;History &amp; Milestones&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/history-milestones.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">History &amp; Milestones</a></li>
#
#                                         <li><a href="/en/about-isb/sustainability-at-isb.html" title="Sustainability at ISB" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/about-isb/sustainability-at-isb.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Sustainability at ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/sustainability-at-isb.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Sustainability at ISB</a></li>
#                                     </ul>
#                                 </div>
#                             </li>
#
#                             <li class="sub-menu">
#                                 <a href="/en/research-thought-leadership.html" title="FACULTY &amp; RESEARCH" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;FACULTY &amp; RESEARCH&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">FACULTY &amp; RESEARCH</a>
#                                 <div class="dropdown-content">
#                                     <ul>
#                                         <li><a href="/en/research-thought-leadership/faculty/faculty-directory.html" title="Faculty Directory" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-directory.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Faculty Directory&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-directory.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Faculty Directory</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/faculty/area-leaders.html" title="Area Leaders" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/area-leaders.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Area Leaders&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/area-leaders.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Area Leaders</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/research-grid.html" title="Research Directory" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-grid.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Research Directory&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-grid.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Research Directory</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/research-centres-institutes.html" title="Research Centres &amp; Institutes" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-centres-institutes.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Research Centres &amp; Institutes&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-centres-institutes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Research Centres &amp; Institutes</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/initiatives.html" title="Initiatives" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/initiatives.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Initiatives&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/initiatives.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Initiatives</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/faculty/faculty-recruitment.html" title="Faculty Recruitment" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-recruitment.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Faculty Recruitment&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-recruitment.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Faculty Recruitment</a></li>
#
#                                         <li><a href="/en/research-thought-leadership/irb.html" title=" Institutional Review Board (IRB)" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/research-thought-leadership/irb.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; Institutional Review Board (IRB)&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/irb.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"> Institutional Review Board (IRB)</a></li>
#                                     </ul>
#                                 </div>
#                             </li>
#
#                             <li class="sub-menu">
#                                 <a href="/en/study-isb.html" title="STUDY AT ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;STUDY AT ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">STUDY AT ISB</a>
#                                 <div class="dropdown-content">
#                                     <ul>
#                                         <li><a href="/en/study-isb/post-graduate-programmes.html" title="Post Graduate Programmes" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/study-isb/post-graduate-programmes.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Post Graduate Programmes&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/post-graduate-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Post Graduate Programmes</a></li>
#
#                                         <li><a href="/en/study-isb/advanced-management-programmes.html" title="Advanced Management Programmes" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/study-isb/advanced-management-programmes.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Advanced Management Programmes&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/advanced-management-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Advanced Management Programmes</a></li>
#
#                                         <li><a href="/en/study-isb/doctoral-studies.html" title="Doctoral Studies" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/study-isb/doctoral-studies.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Doctoral Studies&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/doctoral-studies.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Doctoral Studies</a></li>
#
#                                         <li><a href="/en/study-isb/ivi.html" title="I-Venture Immersive" data-isb-event-info="{&quot;link_click&quot;:&quot;/content/sites/isb/en/study-isb/ivi.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;I-Venture Immersive&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/ivi.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">I-Venture Immersive</a></li>
#                                     </ul>
#                                 </div>
#                             </li>
#
#                             <li class="sub-menu">
#                                 <a href="https://online.isb.edu/?utm_source=isbedu&amp;utm_medium=Nav_Header" title="ISB Online" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;ISB Online&quot;, &quot;linkUrl&quot;:&quot;https://online.isb.edu/?utm_source=isbedu&amp;utm_medium=Nav_Header&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">ISB Online</a>
#                                 <div class="dropdown-content">
#
#                                 </div>
#                             </li>
#
#                             <li class="sub-menu">
#                                 <a href="https://execed.isb.edu/en.html" title="EXECUTIVE EDUCATION" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;EXECUTIVE EDUCATION&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">EXECUTIVE EDUCATION</a>
#                                 <div class="dropdown-content">
#                                     <ul>
#                                         <li><a href="https://execed.isb.edu/en/individual-programmes.html" title="Programmes for Individuals" data-isb-event-info="{&quot;link_click&quot;:&quot;https://execed.isb.edu/en/individual-programmes.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Programmes for Individuals&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/individual-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Programmes for Individuals</a></li>
#
#                                         <li><a href="https://execed.isb.edu/en/enterprise-solutions.html" title="Enterprise Solutions" data-isb-event-info="{&quot;link_click&quot;:&quot;https://execed.isb.edu/en/enterprise-solutions.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Enterprise Solutions&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/enterprise-solutions.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Enterprise Solutions</a></li>
#
#                                         <li><a href="https://execed.isb.edu/en/psu-solutions.html" title="Public Sector Programmes" data-isb-event-info="{&quot;link_click&quot;:&quot;https://execed.isb.edu/en/psu-solutions.html&quot;}, &quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Public Sector Programmes&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/psu-solutions.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Public Sector Programmes</a></li>
#                                     </ul>
#                                 </div>
#                             </li>
#                         </ul>
#                         <div class="sub-menu apply-now">
#                             <div></div>
#
#                             <div class="dropdown-content" id="apply-copy">
#                                 <div class="dd-top">
#
#                                 </div>
#
#                             </div>
#                         </div>
#                 </div></nav>
#
#                 <ul class="top-nav">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <li class="hidden-xs"><a href="/en/give-to-isb.html" title="">Give to ISB</a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     <li>
#                         <a href="#searchModal" data-toggle="modal" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/search.svg" alt="svgicon"></a>
#
#                     </li>
#                     <li>
#                         <a href="javascript:;" class="menu" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/menu1.svg" alt="svgicon"></a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </header>
# </div>
# <div class="mobile-menu">
#
#     <div class="text-right">
#         <a href="javascript:;" class="close-menu" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/close.svg" height="25" width="25" alt=""></a>
#     </div>
#     <div class="first-menu">
#         <ul class="mobile-nav">
#             <li>
#
#                     <a href="#ABOUTISB" class="sub-nav" title=""><strong>ABOUT</strong>  ISB</a>
#
#
#             </li>
#             <li>
#
#             </li>
#
#
#             <li>
#
#                     <a href="#FACULTYRESEARCH" class="sub-nav" title=""><strong>FACULTY</strong>  &amp; RESEARCH</a>
#
#
#             </li>
#             <li>
#
#             </li>
#
#
#             <li>
#
#                     <a href="#STUDYATISB" class="sub-nav" title=""><strong>STUDY</strong>  AT ISB</a>
#
#
#             </li>
#             <li>
#
#             </li>
#
#
#             <li>
#
#
#                     <a href="https://online.isb.edu/?utm_source=isbedu&amp;utm_medium=Nav_Header" class="" title=""><strong>ISB</strong>  Online</a>
#
#             </li>
#             <li>
#
#             </li>
#
#
#             <li>
#
#                     <a href="#EXECUTIVEEDUCATION" class="sub-nav" title=""><strong>EXECUTIVE</strong>  EDUCATION</a>
#
#
#             </li>
#             <li>
#
#             </li>
#
#             	<li id="profileLinkMobile">
#
#             	</li>
#
#         </ul>
#         <hr>
#
#
#                 <ul class="mobile-nav op1">
#
#                         <li>
#                             <a href="/en/news.html" title="News" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;News&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/news.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">News</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/news-events/events-grid.html" title="Events" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Events&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/news-events/events-grid.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Events</a>
#                         </li>
#
#                         <li>
#                             <a href="https://er.isb.edu/en.html.html" title="External Relations" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;External Relations&quot;, &quot;linkUrl&quot;:&quot;https://er.isb.edu/en.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">External Relations</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/i-ventute---isb.html" title="I-Venture @ ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;I-Venture @ ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/i-ventute---isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">I-Venture @ ISB</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/alumni.html" title="Alumni" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Alumni&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/alumni.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Alumni</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/hire-from-isb.html" title="Hire from ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Hire from ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/hire-from-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Hire from ISB</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/careers/careers-at-isb.html" title="Careers" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Careers&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/careers/careers-at-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Careers</a>
#                         </li>
#
#                         <li>
#                             <a href="/en/give-to-isb.html" title="Give to ISB" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Give to ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/give-to-isb.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}">Give to ISB</a>
#                         </li>
#
#                 </ul>
#
#
#
#
#     </div>
#     <div class="second-menu">
#
#             <div id="ABOUTISB">
#                 <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="">ABOUT ISB
#                 </a>
#                 <ul class="mobile-nav">
#                     <li><a href="/en/about-isb.html" title=""> <strong>Overview</strong></a></li>
#
#                         <li><a href="/en/about-isb/leadership.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; Leadership&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/leadership.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Leadership</strong> </a></li>
#
#                         <li><a href="/en/about-isb/isb-advantage.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; ISB&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/isb-advantage.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> ISB</strong> Advantage </a></li>
#
#                         <li><a href="/en/about-isb/partnerships-associations.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; Partnerships&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/partnerships-associations.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Partnerships</strong> &amp; Associations </a></li>
#
#                         <li><a href="/en/about-isb/history-milestones.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; History&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/history-milestones.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> History</strong> &amp; Milestones </a></li>
#
#                         <li><a href="/en/about-isb/sustainability-at-isb.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot; Sustainability&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/about-isb/sustainability-at-isb.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Sustainability</strong> at ISB </a></li>
#
#                 </ul>
#             </div>
#             <div id="ABOUTISB">
#
#
#             </div>
#             <div id="ABOUTISB">
#
#
#             </div>
#             <div id="ABOUTISB">
#
#
#             </div>
#             <div id="ABOUTISB">
#
#
#             </div>
#
#             <div id="FACULTYRESEARCH">
#
#
#             </div>
#             <div id="FACULTYRESEARCH">
#                 <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="">FACULTY &amp; RESEARCH</a>
#                 <ul class="mobile-nav">
#                     <li><a href="/en/research-thought-leadership.html" title=""> <strong>Overview</strong></a></li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/faculty/faculty-directory.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Faculty&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-directory.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Faculty</strong> Directory </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/faculty/area-leaders.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Area&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/area-leaders.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Area</strong> Leaders </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/research-grid.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Research&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-grid.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Research</strong> Directory </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/research-centres-institutes.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Research&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/research-centres-institutes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Research</strong> Centres &amp; Institutes </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/initiatives.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Initiatives&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/initiatives.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Initiatives</strong> </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/faculty/faculty-recruitment.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Faculty&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/faculty/faculty-recruitment.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Faculty</strong> Recruitment </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/research-thought-leadership/irb.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Institutional&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/research-thought-leadership/irb.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Institutional</strong>l Review Board (IRB) </a>
#                         </li>
#
#                 </ul>
#             </div>
#             <div id="FACULTYRESEARCH">
#
#
#             </div>
#             <div id="FACULTYRESEARCH">
#
#
#             </div>
#             <div id="FACULTYRESEARCH">
#
#
#             </div>
#
#             <div id="STUDYATISB">
#
#
#             </div>
#             <div id="STUDYATISB">
#
#
#             </div>
#             <div id="STUDYATISB">
#                 <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="">STUDY AT ISB</a>
#                 <ul class="mobile-nav">
#                     <li><a href="/en/study-isb.html" title=""> <strong>Overview</strong></a></li>
#
#                         <li>
#                             <a href="/en/study-isb/post-graduate-programmes.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Post&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/post-graduate-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Post</strong> Graduate Programmes </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/study-isb/advanced-management-programmes.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Advanced&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/advanced-management-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Advanced</strong> Management Programmes </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/study-isb/doctoral-studies.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Doctoral&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/doctoral-studies.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Doctoral</strong> Studies </a>
#                         </li>
#
#                         <li>
#                             <a href="/en/study-isb/ivi.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;I-Venture&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/ivi.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> I-Venture</strong> Immersive </a>
#                         </li>
#
#                 </ul>
#             </div>
#             <div id="STUDYATISB">
#
#
#             </div>
#             <div id="STUDYATISB">
#
#
#             </div>
#
#             <div id="ISBOnline">
#
#
#             </div>
#             <div id="ISBOnline">
#
#
#             </div>
#             <div id="ISBOnline">
#
#
#             </div>
#             <div id="ISBOnline">
#                 <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="">ISB Online</a>
#                 <ul class="mobile-nav">
#                     <li><a href="https://online.isb.edu/?utm_source=isbedu&amp;utm_medium=Nav_Header" title=""> <strong>Overview</strong></a></li>
#
#                 </ul>
#             </div>
#             <div id="ISBOnline">
#
#
#             </div>
#
#             <div id="EXECUTIVEEDUCATION">
#
#
#             </div>
#             <div id="EXECUTIVEEDUCATION">
#
#
#             </div>
#             <div id="EXECUTIVEEDUCATION">
#
#
#             </div>
#             <div id="EXECUTIVEEDUCATION">
#
#
#             </div>
#             <div id="EXECUTIVEEDUCATION">
#                 <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="">EXECUTIVE EDUCATION</a>
#                 <ul class="mobile-nav">
#                     <li><a href="https://execed.isb.edu/en.html" title=""> <strong>Overview</strong></a></li>
#
#                         <li>
#                             <a href="https://execed.isb.edu/en/individual-programmes.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Programmes&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/individual-programmes.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Programmes</strong> for Individuals </a>
#                         </li>
#
#                         <li>
#                             <a href="https://execed.isb.edu/en/enterprise-solutions.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Enterprise&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/enterprise-solutions.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Enterprise</strong> Solutions </a>
#                         </li>
#
#                         <li>
#                             <a href="https://execed.isb.edu/en/psu-solutions.html" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;Public&quot;, &quot;linkUrl&quot;:&quot;https://execed.isb.edu/en/psu-solutions.html.html&quot;,&quot;linkPosition&quot;:&quot;Header&quot;}"><strong> Public</strong> Sector Programmes </a>
#                         </li>
#
#                 </ul>
#             </div>
#     </div>
# <div class="apply-menu">
#     <div>
#         <a href="javascript:;" class="back-main" title=""><img loading="lazy" src="/content/dam/sites/isb/icons/left-arw.svg" height="25" width="30" alt="lefticon"> BACK
#         </a>
#         <div class="apply-body sub-menu apply-now"><div class="dropdown-content" id="apply-copy">
#                                 <div class="dd-top">
#
#                                 </div>
#
#                             </div></div>
#     </div>
# </div>
# </div>
# <!--profileModal -->
# <div class="modal fade profile-modal" id="profileModal" role="dialog">
#     <div class="modal-dialog modal-lg">
#         <button type="button" class="close" data-dismiss="modal"><img loading="lazy" src="/content/dam/sites/isb/icons/close.svg" alt="">
#         </button>
#         <div class="modal-content">
#             <div class="modal-body">
#                 <div class="setting-bx">
#                     <h3>ISB Experience Tailored to you</h3>
#                     <p>Help us tailor the website experience to your taste. Make some selections to let the website work better for you.
#                     </p>
#                     <p class="sb-title">I am Interested in</p>
#                     <ul class="list-inline tags-list">
#                         <li><a class="active" href="javascript:;">SALES</a></li>
#                         <li><a href="javascript:;">ENTREPRENEUERSHIP</a></li>
#                         <li><a class="active" href="javascript:;">GENERAL MANAGEMENT</a></li>
#                         <li><a class="active" href="javascript:;">POLICY MAKING</a></li>
#                         <li><a class="active" href="javascript:;">Marketing</a></li>
#                         <li><a href="javascript:;">IT &amp; ANALYTICS</a></li>
#                         <li><a class="active" href="javascript:;">HEALTH</a></li>
#                         <li><a class="active" href="javascript:;">FAMILY BUSINESS</a></li>
#                     </ul>
#                     <p class="sb-title">Suggestions for You</p>
#                     <div class="row img-card">
#                         <div class="col-md-4 col-sm-4 col-xs-12">
#                             <a class="res-img img-animate" href="">
#                                 <img loading="lazy" src="/content/dam/sites/isb/images/res-img01.jpg" alt="" class="img-responsive" width="100%">
#                                 <p>PGP MFAB</p>
#                             </a>
#                         </div>
#                         <div class="col-md-4 col-sm-4 col-xs-12">
#                             <a class="res-img img-animate" href="">
#                                 <img loading="lazy" src="/content/dam/sites/isb/images/res-img02.jpg" alt="" class="img-responsive" width="100%">
#                                 <p>Research Centre</p>
#                             </a>
#                         </div>
#                         <div class="col-md-4 col-sm-4 col-xs-12">
#                             <a class="res-img img-animate" href="">
#                                 <img loading="lazy" src="/content/dam/sites/isb/images/res-img03.jpg" alt="" class="img-responsive" width="100%">
#                                 <p>Published Papers</p>
#                             </a>
#                         </div>
#                     </div>
#                     <p>
#                         <a class="buttton blue2" href="#">View Complete Profile</a>
#                     </p>
#                     <div class="btn-group selectP">
#                         <div class="btn-group bootstrap-select outline blue2">
#                             <button type="button" class="btn dropdown-toggle bs-placeholder btn-default" data-toggle="dropdown" role="button" data-id="" title="Alumni"><span class="filter-option pull-left">Alumni</span>&nbsp;<span class="bs-caret"><span class="caret"></span></span>
#                             </button>
#                             <div class="dropdown-menu open" role="combobox">
#                                 <ul class="dropdown-menu inner" role="listbox" aria-expanded="false">
#                                     <li data-original-index="1"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-1</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li>
#                                     <li data-original-index="2"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-2</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li>
#                                     <li data-original-index="3"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-3</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li>
#                                 </ul>
#                             </div>
#                             <div class="btn-group bootstrap-select outline blue2"><button type="button" class="btn dropdown-toggle bs-placeholder btn-default" data-toggle="dropdown" role="button" title="Alumni"><span class="filter-option pull-left">Alumni</span>&nbsp;<span class="bs-caret"><span class="caret"></span></span></button><div class="dropdown-menu open" role="combobox"><ul class="dropdown-menu inner" role="listbox" aria-expanded="false"><li data-original-index="1"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-1</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="2"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-2</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li><li data-original-index="3"><a tabindex="0" class="" data-tokens="null" role="option" aria-disabled="false" aria-selected="false"><span class="text">Alumni-3</span><span class="glyphicon glyphicon-ok check-mark"></span></a></li></ul></div><select class="selectpicker outline blue2" name="" title="Alumni" tabindex="-98">
#                                 <option class="bs-title-option" value="">Alumni</option>
#                                 <option value="1">Alumni-1</option>
# ...
#             </div>
# 	     </div>
#
# </footer></div>
#
#
# </div>
#
# </div></div>
#
#
# </div>
#
#
# </div>
# </div>
#
#     </div>
# </div>
# <!--Start of SuperBot Chat Script-->
# <script type="text/javascript" async="">
#     if(window.location.pathname.includes('/study-isb/')) {
#         if(window.location.pathname.includes('/study-isb/post-graduate-programmes')) {
#             if(window.location.pathname.includes('/study-isb/post-graduate-programmes/pgpmax')) {
#                 var whatsAppConnect = document.createElement("div");
#                 whatsAppConnect.setAttribute('class','whatsappconnect');
#                 whatsAppConnect.innerHTML  = `<a target="_blank" href="https://wa.me/917036031666"><img src="/content/dam/sites/isb/icons/whatsapp.svg"/></a>`;
#                 document.body.appendChild(whatsAppConnect);
#             }
#             var scriptElm = document.createElement('script');
#             scriptElm.setAttribute('class', 'class-name');
#             var inlineCode = document.createTextNode('window.$superbot||(function(d,s){var _sb=$superbot=function(c){_sb._.push(c)},$=_sb.s=d.createElement(s),e=d.getElementsByTagName(s)[0];_sb.set=function(o){_sb.set._.push(o)};_sb._=[];_sb.set._=[];$.async=!0;$.setAttribute("charset","utf-8");$.src="https://app.superbot.works/agent.js?a=kAbLEDag24&l=en";_sb.t=+new Date;$.type="text/javascript";e.parentNode.insertBefore($,e)})(document,"script");');
#             scriptElm.appendChild(inlineCode);
#             inlineCode=document.createTextNode('var _sb_visitor="";');
#             scriptElm.appendChild(inlineCode);
#             document.body.appendChild(scriptElm);
#         }
#     }
# </script>
# <!--End of SuperBot Chat Script-->
#
#
#
#
#
#
#
#
#
#
# <script src="/etc.clientlibs/core/wcm/components/commons/site/clientlibs/container.min.js"></script>
# <script src="/etc.clientlibs/clientlibs/granite/jquery.min.js"></script>
# <script src="/etc.clientlibs/isb/clientlibs/plugin-jquery.min.js"></script>
# <script src="/etc.clientlibs/isb/clientlibs/clientlib-base.min.js"></script>
#
#
#
#
#
#     <!-- Start of HubSpot Embed Code -->
#     <script type="text/javascript" id="hs-script-loader" async="" defer="" src="//js.hs-scripts.com/45398349.js"></script>
#     <!-- End of HubSpot Embed Code -->
#
#
#
#
#
#
#
#
#
#
#
# <script src="/etc.clientlibs/core/wcm/components/commons/datalayer/v1/clientlibs/core.wcm.components.commons.datalayer.v1.min.js"></script>
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1834128646684635");fbq("set","agent","tmgoogletagmanager","1834128646684635");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1834128646684635&amp;ev=PageView&amp;noscript=1"></noscript>
#
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1062787263894396");fbq("set","agent","tmgoogletagmanager","1062787263894396");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1062787263894396&amp;ev=PageView&amp;noscript=1"></noscript>
# <script type="text/javascript" id="">function setCookie(a,b,c){a=a+"\x3d"+b+"; path\x3d/; domain\x3d."+location.hostname.replace(/^www\./i,"");"undefined"!==typeof c&&(b=new Date,b.setTime(b.getTime()+864E5*c),a+="; expires\x3d"+b.toUTCString());document.cookie=a}function getCookie(a){for(var b=document.cookie.split(";"),c,d=0;d<b.length;d++){var e=b[d].trim();0===e.indexOf(a+"\x3d")&&(c=e.substring((a+"\x3d").length,e.length))}return c}
# (function(){var a=getCookie("pageviewCount");"undefined"===typeof a?a=1:a++;setCookie("pageviewCount",a,30)})();</script><script type="text/javascript" id="gtm-engagement-timer">(function(b,a){function f(c,b,d){var a="on"+b;c.addEventListener?c.addEventListener(b,d):c.attachEvent?c.attachEvent(a,function(a){return d.call(c,a)}):"undefined"===typeof c[a]&&(c[a]=function(a){var b=a;return function(a){b&&b.apply(c,a);return d.call(c,a)}}(c[a]))}function k(a){return"undefined"!==typeof a}function F(a,b){var d,c,g,e=null,h=0,l=function(){h=new Date;e=null;g=a.apply(d,c)};return function(){var f=new Date;h||(h=f);var k=b-(f-h);d=this;c=arguments;0>=k?(clearTimeout(e),e=null,h=
# f,g=a.apply(d,c)):e||(e=setTimeout(l,k));return g}}function w(){var c=+new Date;a.performance&&a.performance.timing&&a.performance.timing.domInteractive&&(c=a.performance.timing.domInteractive);return c}a.EngagementTimer=a.EngagementTimer||function(){function c(d){function c(a,d){r[a]=r[a]||[];r[a].push(d)}function g(){clearInterval(n);t=+new Date;n=setInterval(function(){var a=+new Date;p+=Math.ceil((a-t)/1E3);H();t=a},1E3);l("start",{data:{timestamp:t}})}function e(){clearInterval(n);n=!1;l("pause",
# {data:{timestamp:+new Date}})}function h(){p=0;x={};m=0;l("reset",{data:{timestamp:+new Date}})}function l(a,d){var c=r[a],b;if(c)for(b=0;b<c.length;b++)w(c[b],d)}function w(a,d){setTimeout(function(){a(d)},0)}function G(){clearTimeout(y);y=setTimeout(A,B);n||g()}function A(){e();l("idle",{data:{time:p}})}function I(a){setTimeout(function(){x[a]||a>J||a<K||(l("interval",{data:{time:a}}),x[a]=!0,m=a>m?a:m)},0)}function H(){var a=[],c=0,b;if(C.length)for(b=0;b<d.every.length;b++){var f=C[b];var e=Math.floor(p/
# f)*f;if(e<m)break;for(;e>m&&0<e&&50>c;)a.push(e),e=Math.max(0,e-f),c++}if(D.length)for(b=0;b<d.each.length;b++)f=D[b],f>m&&f<=p&&a.push(f);a.sort(function(a,b){return a>b?1:b>a?-1:0});for(b=0;b<a.length;b++)I(a[b])}var L=d.target||b,z=+new Date,p=Math.ceil((z-(d.startTime||E))/1E3),r={},x={},J=d.max||Infinity,K=d.min||0,C=d.every||[],D=d.each||[],B=1E3*(d.idleAfter-1),m=0,t,n,u;clearTimeout(y);var y=setTimeout(A,B);setTimeout(g,0);if(!d.engagementEvents||!d.engagementEvents.length)throw"Missing required configuration 'engagementEvents'";
# for(u=0;u<d.engagementEvents.length;u++)z=d.engagementEvents[u],f(L,z,F(G,500));if(d.idleOnVisibilityChange){if(k(b.hidden)){var v="hidden";var q="visibilitychange"}else k(b.mozHidden)?(v="mozHidden",q="mozvisibilitychange"):k(b.msHidden)?(v="msHidden",q="msvisibilitychange"):k(b.webkitHidden)&&(v="webkitHidden",q="webkitvisibilitychange");q?f(b,q,function(a){b[v]?e():g()}):(f(a,"blur",e),f(a,"focus",g))}return{on:c,start:g,pause:e,reset:h}}var E=w();return c}()})(document,window);
# (function(b){var a=EngagementTimer({every:[Number(google_tag_manager["rm"]["10333454"](49))],idleAfter:Number(google_tag_manager["rm"]["10333454"](50)),engagementEvents:["click","touchstart","scroll","keydown","mousemove"],idleOnVisibilityChange:!0,max:Number(google_tag_manager["rm"]["10333454"](51)),min:Number(google_tag_manager["rm"]["10333454"](52))});a.on("interval",function(a){b.dataLayer.push({event:"engagementTimer",attributes:{counter:a.data.time}})});b.EngagementTimer=null})(window);</script><script type="text/javascript" id="">var onWindow=function(b,a){"undefined"!==typeof window.addEventListener?window.addEventListener(b,a,!1):window.attachEvent("on"+b,function(){a.call(window)})},onWindowLeave=function(b){onWindow("mouseout",function(a){a=a?a:window.event;(a=a.relatedTarget||a.toElement)&&"HTML"!==a.nodeName||"function"===typeof b&&b()})};onWindowLeave(function(){dataLayer.push({event:"exit_intent"})});</script>
#
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","2378635972356531");fbq("set","agent","tmgoogletagmanager","2378635972356531");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2378635972356531&amp;ev=PageView&amp;noscript=1"></noscript>
#
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1141711772648192");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1141711772648192&amp;ev=PageView&amp;noscript=1"></noscript>
# <script type="text/javascript" id="">(function(a,e,b,f,g,c,d){a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};c=e.createElement(f);c.async=1;c.src="https://www.clarity.ms/tag/"+g;d=e.getElementsByTagName(f)[0];d.parentNode.insertBefore(c,d)})(window,document,"clarity","script","3wd0u1o8ei");</script>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","2434434326878006");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2434434326878006&amp;ev=PageView&amp;noscript=1"></noscript>
#
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","366639254146581");fbq("set","agent","tmgoogletagmanager","366639254146581");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=366639254146581&amp;ev=PageView&amp;noscript=1"></noscript>
# <script type="text/javascript" id="">(function(a,e,b,f,g,c,d){a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};c=e.createElement(f);c.async=1;c.src="https://www.clarity.ms/tag/"+g+"?ref\x3dgtm2";d=e.getElementsByTagName(f)[0];d.parentNode.insertBefore(c,d)})(window,document,"clarity","script","kwvjvan8pv");</script>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","366639254146581");fbq("set","agent","gtmss","366639254146581");fbq("track",google_tag_manager["rm"]["10333454"](55),{},{eventID:google_tag_manager["rm"]["10333454"](57)});</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=366639254146581&amp;ev=PageView&amp;noscript=1"></noscript>
# <img src="https://t.co/i/adsct?bci=3&amp;eci=2&amp;event_id=a57a7b64-928b-4322-b42e-c2072daee6ac&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=1dbc76c4-7fe5-4d40-80fd-ab1bd5893daf&amp;tw_document_href=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o1y2k&amp;type=javascript&amp;version=2.3.30" height="1" width="1" style="display: none;"><img src="https://analytics.twitter.com/i/adsct?bci=3&amp;eci=2&amp;event_id=a57a7b64-928b-4322-b42e-c2072daee6ac&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=1dbc76c4-7fe5-4d40-80fd-ab1bd5893daf&amp;tw_document_href=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o1y2k&amp;type=javascript&amp;version=2.3.30" height="1" width="1" style="display: none;"><img src="https://t.co/i/adsct?bci=3&amp;eci=2&amp;event_id=d4f0ef29-04fc-4790-b5bf-27416d1b2e84&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=1dbc76c4-7fe5-4d40-80fd-ab1bd5893daf&amp;tw_document_href=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o3kpb&amp;type=javascript&amp;version=2.3.30" height="1" width="1" style="display: none;"><img src="https://analytics.twitter.com/i/adsct?bci=3&amp;eci=2&amp;event_id=d4f0ef29-04fc-4790-b5bf-27416d1b2e84&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=1dbc76c4-7fe5-4d40-80fd-ab1bd5893daf&amp;tw_document_href=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o3kpb&amp;type=javascript&amp;version=2.3.30" height="1" width="1" style="display: none;"><iframe id="_hjSafeContext_58421389" title="_hjSafeContext" tabindex="-1" aria-hidden="true" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;"></iframe><div id="batBeacon487644860492" style="width: 0px; height: 0px; display: none; visibility: hidden;"><img id="batBeacon37105509410" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=97091014&amp;tm=gtm002&amp;Ver=2&amp;mid=9b538c36-7c0d-473f-983e-6b3f42831251&amp;sid=71abd9c057ba11ef9f3b2fdd11de739d&amp;vid=71ac189057ba11ef95d3e3d48eb2f764&amp;vids=1&amp;msclkid=N&amp;gtm_tag_source=1&amp;uach=pv%3D15.0.0&amp;pi=918639831&amp;lg=en-US&amp;sw=1280&amp;sh=800&amp;sc=24&amp;nwd=1&amp;tl=Advanced%20Management%20Programme&amp;p=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;r=&amp;lt=600&amp;evt=pageLoad&amp;sv=1&amp;cdb=AQAQ&amp;rn=451572" style="width: 0px; height: 0px; display: none; visibility: hidden;"><img id="batBeacon331515987763" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=97091014&amp;tm=gtm002&amp;Ver=2&amp;mid=9b538c36-7c0d-473f-983e-6b3f42831251&amp;sid=71abd9c057ba11ef9f3b2fdd11de739d&amp;vid=71ac189057ba11ef95d3e3d48eb2f764&amp;vids=0&amp;msclkid=N&amp;gtm_tag_source=ua&amp;ec=Page%20Load%20Time&amp;el=3&amp;ev=3&amp;gc=INR&amp;tpp=1&amp;en=Y&amp;p=https%3A%2F%2Fwww.isb.edu%2Fen%2Fstudy-isb%2Fadvanced-management-programmes.html&amp;sw=1280&amp;sh=800&amp;sc=24&amp;nwd=1&amp;evt=custom&amp;cdb=AQAQ&amp;rn=889901" style="width: 0px; height: 0px; display: none; visibility: hidden;"><img id="batBeacon518963599497" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=97091014&amp;tm=gtm002&amp;Ver=2&amp;mid=9b538c36-7c0d-473f-983e-6b3f42831251&amp;sid=71abd9c057ba11ef9f3b2fdd11de739d&amp;vid=71ac189057b ...

# %% [markdown]
# #### **Step 3-** Extracting data from HTML

# %%
Prog_info = body.find_elements(By.CSS_SELECTOR, 'li.cmp-list__item')
# This will generate a list object of class with all objects with tag "li" that meet the criteria for class
for item in Prog_info:
    print(item.text)
# Out:
# Advanced Management Programme in Business Analytics (AMPBA)
# Designed for professionals who want to build or enhance their understanding of data & analytics to inform business decision-making
# Duration: 12 months + 3 months of Capstone Project
# Work Experience: 2+ years
# Location: Hyderabad | Mohali
# APPLY
# KNOW MORE
# Advanced Management Programme for Healthcare (AMPH)
# Meant to deliver specialised management education to executives from the healthcare-delivery industry, and those who want to build domain expertise
# Duration: 12 months
# Work Experience: 3+ years
# Location: Mohali | Hyderabad
# APPLY
# KNOW MORE
# Advanced Management Programme for Infrastructure (AMPI)
# Specialised programme for professionals who want to build or enhance expertise in the multidisciplinary sector of infrastructure, with focus on emerging economies
# Duration: 12 months
# Work Experience: 5+ years
# Location: Mohali and Hyderabad
# APPLY
# KNOW MORE
# Advanced Management Programme in Operations and Supply Chain (AMPOS)
# Designed to meet the increasing need for specialised executives working in manufacturing and operations, aligned with India's focus on these sectors
# Duration: 12 months
# Work Experience: 5+ years
# Location: Mohali and Hyderabad
# APPLY
# KNOW MORE
# Advanced Management Programme in Public Policy (AMPPP)
# Specialised programme for the needs of mid-career and senior-level professionals from the public and private sectors, aimed at refining their understanding of policy design and implementation
# Duration: 12 months
# Work Experience: 5+ years
# Location: Hyderabad and Mohali
# APPLY
# KNOW MORE

# %%
len(Prog_info)
# Out:
# 5

# %%
# let me save the outer html for each object as a list using list comprehension
Prog_info_html = [prog.get_attribute('outerHTML') for prog in Prog_info]

# %%
# How many items do we have in this temp object?
len(Prog_info_html)

# There are 5 programs on this page.
# Out:
# 5

# %%
# Lets inspect the first element in the list
Prog_info_html[0]
# Out:
# '<li class="cmp-list__item">\n   \t   <div class="row card-4-container">\n         <div class="col-md-12 col-sm-12">\n            <div class="card-4">\n               <figure>\n                  <img loading="lazy" class="img-responsive" src="/content/dam/sites/isb/study-isb/advanced-management-programmes/AMP-AMPBA-Common-Thumbs.png" alt="imageAltText">\n               </figure>\n               <div class="card-detail">\n                  <span class="award-icon"><img loading="lazy" src="/content/dam/sites/isb/images/award-ic.png" alt=""></span>\n                  <div class="head-bx">\n                     <div class="tag"></div>\n                     <h3>Advanced Management Programme in Business Analytics (AMPBA)</h3>\n                     <h4>Designed for professionals who want to build or enhance their understanding of data &amp; analytics to inform business decision-making</h4>\n                  </div>\n                  <div class="info-bx">\n                     <div class="row">\n                        <div class="col-md-6 col-xs-6 bor-botom">\n                           Duration: <strong>12 months + 3 months of Capstone Project</strong>\n                        </div>\n                        <div class="col-md-6 col-xs-6 bor-botom">\n                           Work Experience: <strong>2+ years </strong>\n                        </div>\n                     </div>                    \n                    <div class="row">\n                        <div class="col-md-12 col-xs-12">\n                           <p>Location: <strong>Hyderabad | Mohali</strong></p>\n                           \n                        </div>\n                    </div>                     \n                  </div>\n                  <p class="more">\n                    <a href="https://admissions.isb.edu/ampba?utm_source=website&amp;utm_medium=amp-page&amp;utm_campaign=amp-page" class="buttton op1" target="_blank" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;APPLY&quot;, &quot;linkUrl&quot;:&quot;https://admissions.isb.edu/ampba?utm_source=website&amp;utm_medium=amp-page&amp;utm_campaign=amp-page&quot;,&quot;linkPosition&quot;:&quot;Master Program&quot;}">APPLY</a>\n                     <a href="/en/study-isb/advanced-management-programmes/business-analytics.html" class="buttton link" target="_blank" title="" data-isb-event-info="{&quot;linkType&quot;:&quot;link&quot;, &quot;linkName&quot;: &quot;KNOW MORE&quot;, &quot;linkUrl&quot;:&quot;/content/sites/isb/en/study-isb/advanced-management-programmes/business-analytics.html&quot;,&quot;linkPosition&quot;:&quot;Master Program&quot;}">KNOW MORE</a>\n                  </p>\n               </div>\n            </div>\n         </div>\n   \t\t</div>\n   \t</li>'

# %%
# We need to convert each object in the list into a beautifulsoup object
# We can use a list comprehension to accomplish this

from bs4 import BeautifulSoup
prog_soup = [BeautifulSoup(prog_html) for prog_html in Prog_info_html]

# %%
#Extracting titles
titles = [prog.find("h3").text for prog in prog_soup]
titles

#Extracting Brief description
Description = [prog.find("h4").text for prog in prog_soup]
Description

#Extracting Duration
Duration = [prog.find("strong").text for prog in prog_soup]
Duration

#Extracting Work Exp.
Work_Exp = [prog.find_all("strong")[1].text for prog in prog_soup]
Work_Exp
# Out:
# ['2+ years ', '3+ years ', '5+ years', '5+ years', '5+ years']

# %% [markdown]
# #### **Step 4-** Creation of dataframe

# %% [markdown]
# <span style='color:Blue'> As per **Question 2 (part 2)**, we need to create a dataframe with following fields. <br>
# (i) Title <br>
# (ii) Description <br>
# (iii) Duration (in months) <br>
# (iv) Capstone Project (Yes/ No) <br>
# (v) Work Experience  </span>

# %%
#Creating a dataframe
data = {'Titles': titles, 'Description': Description, 'Duration': Duration, 'Work_Exp': Work_Exp}
df = pd.DataFrame(data)
df
# Out:
#                                                                  Titles  \
# 0           Advanced Management Programme in Business Analytics (AMPBA)
# 1                   Advanced Management Programme for Healthcare (AMPH)
# 2               Advanced Management Programme for Infrastructure (AMPI)
# 3  Advanced Management Programme in Operations and Supply Chain (AMPOS)
# 4                Advanced Management Programme in Public Policy (AMPPP)
#
#                                                                        Description  \
# 0  Designed for professionals who want to build or enhance their understanding ...
# 1  Meant to deliver specialised management education to executives from the hea...
# 2  Specialised programme for professionals who want to build or enhance experti...
# 3  Designed to meet the increasing need for specialised executives working in m...
# 4  Specialised programme for the needs of mid-career and senior-level professio...
#
#                                    Duration   Work_Exp
# 0  12 months + 3 months of Capstone Project  2+ years
# 1                                 12 months  3+ years
# 2                                 12 months   5+ years
# 3                                 12 months   5+ years
# 4                                 12 months   5+ years

# %%
#Updating dataframe
df[['Duration', 'Capstone']] = df['Duration'].str.split('+', expand=True)
df['Capstone']=df['Capstone'].fillna('No')
df
# Out:
#                                                                  Titles  \
# 0           Advanced Management Programme in Business Analytics (AMPBA)
# 1                   Advanced Management Programme for Healthcare (AMPH)
# 2               Advanced Management Programme for Infrastructure (AMPI)
# 3  Advanced Management Programme in Operations and Supply Chain (AMPOS)
# 4                Advanced Management Programme in Public Policy (AMPPP)
#
#                                                                        Description  \
# 0  Designed for professionals who want to build or enhance their understanding ...
# 1  Meant to deliver specialised management education to executives from the hea...
# 2  Specialised programme for professionals who want to build or enhance experti...
# 3  Designed to meet the increasing need for specialised executives working in m...
# 4  Specialised programme for the needs of mid-career and senior-level professio...
#
#      Duration   Work_Exp                       Capstone
# 0  12 months   2+ years    3 months of Capstone Project
# 1   12 months  3+ years                              No
# 2   12 months   5+ years                             No
# 3   12 months   5+ years                             No
# 4   12 months   5+ years                             No

# %%
#Updating dataframe
df['Capstone'] = df['Capstone'].apply(lambda x: 'No' if x == "No" else 'Yes')
import re
pattern= r'(.*)\s+months'
df['Duration'] = df['Duration'].str.extract(pattern)
df['Duration']=df['Duration'].astype(int)
df['Capstone'] = pd.Categorical(df['Capstone'], categories=['No', 'Yes'])
df.rename(columns={'Duration': 'Duration (in months)','Capstone': 'Capstone Project (Yes/No)'}, inplace=True)
df #printing data farme
# Out:
#                                                                  Titles  \
# 0           Advanced Management Programme in Business Analytics (AMPBA)
# 1                   Advanced Management Programme for Healthcare (AMPH)
# 2               Advanced Management Programme for Infrastructure (AMPI)
# 3  Advanced Management Programme in Operations and Supply Chain (AMPOS)
# 4                Advanced Management Programme in Public Policy (AMPPP)
#
#                                                                        Description  \
# 0  Designed for professionals who want to build or enhance their understanding ...
# 1  Meant to deliver specialised management education to executives from the hea...
# 2  Specialised programme for professionals who want to build or enhance experti...
# 3  Designed to meet the increasing need for specialised executives working in m...
# 4  Specialised programme for the needs of mid-career and senior-level professio...
#
#    Duration (in months)   Work_Exp Capstone Project (Yes/No)
# 0                    12  2+ years                        Yes
# 1                    12  3+ years                         No
# 2                    12   5+ years                        No
# 3                    12   5+ years                        No
# 4                    12   5+ years                        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Titles                     5 non-null      object
#  1   Description                5 non-null      object
#  2   Duration (in months)       5 non-null      int32
#  3   Work_Exp                   5 non-null      object
#  4   Capstone Project (Yes/No)  5 non-null      category
# dtypes: category(1), int32(1), object(3)
# memory usage: 401.0+ bytes
